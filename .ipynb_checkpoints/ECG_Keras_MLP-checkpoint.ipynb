# %% [markdown]
# ### MLP for ECG Signal Classification (5 classes)  - Keras
# This is the implementation of an MLP for classifying the ECG signals. <br>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adamax
import matplotlib.pyplot as plt
from IPython import display
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load the data

# %%
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints

# %%
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)
#note: add a channel axis to the data if the network is CNN: see the examples presented in class

# %% [markdown]
# ### Define the MLP model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import *
from tensorflow.keras.layers import AveragePooling1D
import keras.layers.normalization
from tensorflow.keras.layers import LayerNormalization


inputs = Input(shape=(187,))
l1=Dense(187, activation='relu')(inputs)

l2linear = Dense(88,activation='relu')(l1)
reshape1 = Reshape([17,11])(l1)
avg1 = AveragePooling1D(pool_size=2, strides=2)(reshape1)
reshape11 = Reshape([88])(avg1)
added1 = keras.layers.Add()([l2linear, reshape11])

norm_layer1 = LayerNormalization()(added1)
layer3 = Dense(44,activation='relu')(norm_layer1)

reshape2 = Reshape([8,11])(added1)
avg2 = AveragePooling1D(pool_size=2,strides=2)(reshape2)
reshape22 = Reshape([44])(avg2)


added2 = keras.layers.Add()([layer3, reshape22])

norm_layer2 = LayerNormalization()(added2)
layer4 = Dense(22,activation='relu')(norm_layer2)

reshape3 = Reshape([4,11])(added2)
avg3 = AveragePooling1D(pool_size=2,strides=2)(reshape3)
reshape33 = Reshape([22])(avg3)


added3 = keras.layers.Add()([layer4, reshape33])

norm_layer3 = LayerNormalization()(added3)
layer5 = Dense(187,activation='relu')(norm_layer3)

layer6 = Dense(187,activation='relu')(layer5)

output = keras.layers.Activation('softmax')(layer6)

model = Model(inputs=inputs, outputs=output)



model.compile(loss='sparse_categorical_crossentropy', optimizer=Adamax(learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 187)]        0           []
#
#  dense (Dense)                  (None, 187)          35156       ['input_1[0][0]']
#
#  reshape (Reshape)              (None, 17, 11)       0           ['dense[0][0]']
#
#  average_pooling1d (AveragePool  (None, 8, 11)       0           ['reshape[0][0]']
#  ing1D)
#
#  dense_1 (Dense)                (None, 88)           16544       ['dense[0][0]']
#
#  reshape_1 (Reshape)            (None, 88)           0           ['average_pooling1d[0][0]']
#
#  add (Add)                      (None, 88)           0           ['dense_1[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  reshape_2 (Reshape)            (None, 8, 11)        0           ['add[0][0]']
#
#  layer_normalization (LayerNorm  (None, 88)          176         ['add[0][0]']
#  alization)
#
#  average_pooling1d_1 (AveragePo  (None, 4, 11)       0           ['reshape_2[0][0]']
#  oling1D)
#
#  dense_2 (Dense)                (None, 44)           3916        ['layer_normalization[0][0]']
#
#  reshape_3 (Reshape)            (None, 44)           0           ['average_pooling1d_1[0][0]']
#
#  add_1 (Add)                    (None, 44)           0           ['dense_2[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  reshape_4 (Reshape)            (None, 4, 11)        0           ['add_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 44)          88          ['add_1[0][0]']
#  rmalization)
#
#  average_pooling1d_2 (AveragePo  (None, 2, 11)       0           ['reshape_4[0][0]']
#  oling1D)
#
#  dense_3 (Dense)                (None, 22)           990         ['layer_normalization_1[0][0]']
#
#  reshape_5 (Reshape)            (None, 22)           0           ['average_pooling1d_2[0][0]']
#
#  add_2 (Add)                    (None, 22)           0           ['dense_3[0][0]',
#                                                                   'reshape_5[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 22)          44          ['add_2[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 187)          4301        ['layer_normalization_2[0][0]']
#
#  dense_5 (Dense)                (None, 187)          35156       ['dense_4[0][0]']
#
#  activation (Activation)        (None, 187)          0           ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 96,371
# Trainable params: 96,371
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
loss_train_list=[]
loss_val_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# ### Train the model

# %%
epoch = 0
for epoch in range(epoch_save+1, 100): #change 100 to a larger number if necessary
    print('epoch', epoch)
    #set epochs=1
    history=model.fit(X_train, Y_train, batch_size=64, epochs=1, validation_data=(X_val, Y_val))
    loss_train_list.extend(history.history['loss'])
    loss_val_list.extend(history.history['val_loss'])
    acc_train_list.extend(history.history['accuracy'])
    acc_val_list.extend(history.history['val_accuracy'])
    #save the model to a a HDF5 file 
    model.save('ECG_Keras_sCE_e'+str(epoch)+'.h5')
# Out:
# epoch 0
# 44/44 [==============================] - 1s 7ms/step - loss: 4.2515 - accuracy: 0.4280 - val_loss: 3.3717 - val_accuracy: 0.5000
# epoch 1
# 44/44 [==============================] - 0s 3ms/step - loss: 3.0139 - accuracy: 0.5344 - val_loss: 2.9001 - val_accuracy: 0.5227
# epoch 2
# 44/44 [==============================] - 0s 3ms/step - loss: 2.7534 - accuracy: 0.5488 - val_loss: 2.7656 - val_accuracy: 0.5422
# epoch 3
# 44/44 [==============================] - 0s 3ms/step - loss: 2.5573 - accuracy: 0.5622 - val_loss: 2.3897 - val_accuracy: 0.5812
# epoch 4
# 44/44 [==============================] - 0s 3ms/step - loss: 1.9398 - accuracy: 0.6690 - val_loss: 1.8444 - val_accuracy: 0.6526
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0447 - accuracy: 0.9895 - val_loss: 0.8412 - val_accuracy: 0.8247
# epoch 53
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9917 - val_loss: 0.8864 - val_accuracy: 0.8214
# epoch 54
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 0.9888 - val_loss: 0.9410 - val_accuracy: 0.8052
# epoch 55
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9942 - val_loss: 0.9688 - val_accuracy: 0.8182
# epoch 56
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9935 - val_loss: 0.9235 - val_accuracy: 0.8149
# epoch 57
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9931 - val_loss: 0.9702 - val_accuracy: 0.8117
# epoch 58
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9895 - val_loss: 0.9188 - val_accuracy: 0.8344
# epoch 59
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 0.9938 - val_loss: 0.9250 - val_accuracy: 0.8344
# epoch 60
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 0.9938 - val_loss: 0.9569 - val_accuracy: 0.8279
# epoch 61
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 0.9888 - val_loss: 0.9682 - val_accuracy: 0.8247
# epoch 62
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9913 - val_loss: 1.0203 - val_accuracy: 0.8214
# epoch 63
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9946 - val_loss: 0.9682 - val_accuracy: 0.8247
# epoch 64
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9978 - val_loss: 1.0440 - val_accuracy: 0.8344
# epoch 65
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 1.0656 - val_accuracy: 0.8279
# epoch 66
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9949 - val_loss: 1.0815 - val_accuracy: 0.8149
# epoch 67
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 1.0594 - val_accuracy: 0.8312
# epoch 68
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9960 - val_loss: 1.0617 - val_accuracy: 0.8182
# epoch 69
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9964 - val_loss: 1.0386 - val_accuracy: 0.8247
# epoch 70
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.9834 - val_loss: 1.1418 - val_accuracy: 0.8052
# epoch 71
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0400 - accuracy: 0.9863 - val_loss: 1.1709 - val_accuracy: 0.8084
# epoch 72
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 0.9935 - val_loss: 1.1053 - val_accuracy: 0.8182
# epoch 73
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9960 - val_loss: 1.0757 - val_accuracy: 0.8279
# epoch 74
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9986 - val_loss: 1.1113 - val_accuracy: 0.8149
# epoch 75
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9989 - val_loss: 1.0950 - val_accuracy: 0.8214
# epoch 76
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 1.1336 - val_accuracy: 0.8149
# epoch 77
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 1.1413 - val_accuracy: 0.8149
# epoch 78
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9986 - val_loss: 1.1392 - val_accuracy: 0.8149
# epoch 79
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 1.1985 - val_accuracy: 0.8149
# epoch 80
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 1.2316 - val_accuracy: 0.8117
# epoch 81
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9978 - val_loss: 1.1606 - val_accuracy: 0.8084
# epoch 82
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 1.1676 - val_accuracy: 0.8279
# epoch 83
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 1.1960 - val_accuracy: 0.8117
# epoch 84
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 1.1925 - val_accuracy: 0.8182
# epoch 85
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 1.2124 - val_accuracy: 0.8149
# epoch 86
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 1.2380 - val_accuracy: 0.8149
# epoch 87
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 1.2171 - val_accuracy: 0.8214
# epoch 88
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 1.2227 - val_accuracy: 0.8279
# epoch 89
# 44/44 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 1.2340 - val_accuracy: 0.8247
# epoch 90
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 1.2386 - val_accuracy: 0.8214
# epoch 91
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 1.2384 - val_accuracy: 0.8182
# epoch 92
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 1.2592 - val_accuracy: 0.8214
# epoch 93
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 1.2644 - val_accuracy: 0.8149
# epoch 94
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.9931 - val_loss: 1.2509 - val_accuracy: 0.8149
# epoch 95
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9888 - val_loss: 1.2853 - val_accuracy: 0.8019
# epoch 96
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 1.2807 - val_accuracy: 0.8214
# epoch 97
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 1.1969 - val_accuracy: 0.8279
# epoch 98
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9982 - val_loss: 1.2340 - val_accuracy: 0.8149
# epoch 99
# 44/44 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 1.2261 - val_accuracy: 0.8247

# %% [markdown]
# ### Plot training loss vs epoch and validation loss vs epoch

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].plot(np.arange(0,len(loss_train_list)), loss_train_list, '-b', label='training loss')
ax[0].plot(np.arange(0,len(loss_val_list)), loss_val_list, '-r', label='validation loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].plot(np.arange(0,len(acc_train_list)), acc_train_list, '-b', label='training accuracy')
ax[1].plot(np.arange(0,len(acc_val_list)), acc_val_list, '-r', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# ### Test the model

# %%
#load the best model
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 58

# %%
import tensorflow
model = tensorflow.keras.models.load_model("ECG_Keras_sCE_e"+str(best_epoch)+".h5")

# %%
score = model.evaluate(X_test, Y_test, batch_size=64, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.603158712387085
# Test accuracy: 0.8699609637260437

# %% [markdown]
# ### Make Prediction on the test set

# %%
Y_test_pred=model.predict(X_test, batch_size=64)
# Out:
# 13/13 [==============================] - 0s 1ms/step

# %%
Y_test_pred[0]
# Out:
# array([5.3954169e-05, 9.9994445e-01, 6.4206231e-09, 2.8979264e-07,
#        1.2342176e-08, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09, 6.4206231e-09,
#        6.4206231e-09, 6.4206231e-09, 6.4206231e-09], dtype=float32)

# %%
np.argmax(Y_test_pred[0])
# Out:
# 1

# %%
Y_test[0]
# Out:
# 1

# %%
Y_test_pred=np.argmax(Y_test_pred, axis=1)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.79       176
#            1       0.83      0.88      0.85       154
#            2       0.91      0.86      0.88       146
#            3       0.87      0.95      0.91       122
#            4       0.91      0.94      0.93       171
#
#     accuracy                           0.87       769
#    macro avg       0.87      0.88      0.87       769
# weighted avg       0.87      0.87      0.87       769
